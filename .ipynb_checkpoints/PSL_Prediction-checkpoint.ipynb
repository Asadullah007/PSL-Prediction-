# %%
import numpy as np # linear algebra
import pandas as pd 
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras import models, layers, optimizers, utils

import matplotlib.pyplot as plt

# %%
matches=pd.read_csv('./PSL_2016-2020.csv')
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 15 columns):
# Team_1              127 non-null object
# Team_2              127 non-null object
# Team1_Code          127 non-null object
# Team2_Code          127 non-null object
# Season              127 non-null int64
# venue               127 non-null object
# id                  127 non-null int64
# Win_By_Wkts         127 non-null int64
# Win_By_Runs         127 non-null int64
# toss_winner         127 non-null object
# toss_winner_code    127 non-null object
# toss_decision       127 non-null object
# result              127 non-null object
# winner              127 non-null object
# winner_code         127 non-null object
# dtypes: int64(4), object(11)
# memory usage: 15.0+ KB

# %%
matches.head()
# Out:
#                Team_1             Team_2 Team1_Code Team2_Code  Season  venue  \
# 0   ISLAMABAD UNITED   QUETTA GLADIATORS         IU         QG    2016  Dubai
# 1       KARACHI KINGS   LAHORE QALANDARS         KK         LQ    2016  Dubai
# 2      PESHAWAR ZALMI   ISLAMBAD UNITED          PZ         IU    2016  Dubai
# 3  QUETTA GLADIATORS       KARACHI KINGS         QG         KK    2016  Dubai
# 4   LAHORE QALANDARS      PESHAWAR ZALMI         LQ         PZ    2016  Dubai
#
#    id  Win_By_Wkts  Win_By_Runs        toss_winner toss_winner_code  \
# 0   1            8            0   ISLAMABAD UNITED               IU
# 1   2            7            0      KARACHI KINGS               KK
# 2   3            0           24     PESHAWAR ZALMI               PZ
# 3   4            8            0  QUETTA GLADIATORS               QG
# 4   5            9            0     PESHAWAR ZALMI               PZ
#
#   toss_decision  result             winner winner_code
# 0         field  normal  QUETTA GLADIATORS          QG
# 1         field  normal      KARACHI KINGS          KK
# 2         field  normal     PESHAWAR ZALMI          PZ
# 3         field  normal  QUETTA GLADIATORS          QG
# 4           bat  normal     PESHAWAR ZALMI          PZ

# %%
matches.tail()
# Out:
#                Team_1             Team_2 Team1_Code Team2_Code  Season  \
# 122  LAHORE QALANDARS   ISLAMABAD UNITED         LQ         IU    2020
# 123   MULTAN SULTANS      PESHAWAR ZALMI         MS         PZ    2020
# 124  ISLAMABAD UNITED  QUETTA GLADIATORS         IU         QG    2020
# 125   MULTAN SULTANS       KARACHI KINGS         MS         KK    2020
# 126  ISLAMABAD UNITED  QUETTA GLADIATORS         IU         QG    2020
#
#        venue   id  Win_By_Wkts  Win_By_Runs        toss_winner  \
# 122  karachi  122            1            0   LAHORE QALANDARS
# 123  karachi  123            6            0     PESHAWAR ZALMI
# 124  karachi  124            5            0  QUETTA GLADIATORS
# 125  karachi  125            0           52      KARACHI KINGS
# 126  karachi  124            5            0  QUETTA GLADIATORS
#
#     toss_winner_code toss_decision  result              winner winner_code
# 122               LQ         field  normal   ISLAMABAD UNITED           IU
# 123               PZ           bat  normal     MULTAN SULTANS           MS
# 124               QG         field  normal  QUETTA GLADIATORS           QG
# 125               KK         field  normal     MULTAN SULTANS           MS
# 126               QG         field  normal  QUETTA GLADIATORS           QG

# %%
matches[pd.isnull(matches['winner'])]
# Out:
# Empty DataFrame
# Columns: [Team_1, Team_2, Team1_Code, Team2_Code, Season, venue, id, Win_By_Wkts, Win_By_Runs, toss_winner, toss_winner_code, toss_decision, result, winner, winner_code]
# Index: []

# %%
encode = {'Team1_Code': {'KK':1,'LQ':2,'MS':3,'IU':4,'PZ':5 ,'QG':6},
          'Team2_Code': {'KK':1,'LQ':2,'MS':3,'IU':4,'PZ':5 ,'QG':6},
          'toss_winner_code': {'KK':1,'LQ':2,'MS':3,'IU':4,'PZ':5 ,'QG':6},
          'winner_code': {'KK':1,'LQ':2,'MS':3,'IU':4,'PZ':5 ,'QG':6,'MT':7,'MA':10},
         'toss_decision': {'field':1,'bat':2}}
matches.replace(encode,inplace=True)
matches.head()
# Out:
#                Team_1             Team_2  Team1_Code  Team2_Code  Season  \
# 0   ISLAMABAD UNITED   QUETTA GLADIATORS           4           6    2016
# 1       KARACHI KINGS   LAHORE QALANDARS           1           2    2016
# 2      PESHAWAR ZALMI   ISLAMBAD UNITED            5           4    2016
# 3  QUETTA GLADIATORS       KARACHI KINGS           6           1    2016
# 4   LAHORE QALANDARS      PESHAWAR ZALMI           2           5    2016
#
#    venue  id  Win_By_Wkts  Win_By_Runs        toss_winner  toss_winner_code  \
# 0  Dubai   1            8            0   ISLAMABAD UNITED                 4
# 1  Dubai   2            7            0      KARACHI KINGS                 1
# 2  Dubai   3            0           24     PESHAWAR ZALMI                 5
# 3  Dubai   4            8            0  QUETTA GLADIATORS                 6
# 4  Dubai   5            9            0     PESHAWAR ZALMI                 5
#
#    toss_decision  result             winner  winner_code
# 0              1  normal  QUETTA GLADIATORS            6
# 1              1  normal      KARACHI KINGS            1
# 2              1  normal     PESHAWAR ZALMI            5
# 3              1  normal  QUETTA GLADIATORS            6
# 4              2  normal     PESHAWAR ZALMI            5

# %%
matches.describe()
# Out:
#        Team1_Code  Team2_Code       Season          id  Win_By_Wkts  \
# count  127.000000  127.000000   127.000000  127.000000   127.000000
# mean     3.543307    3.755906  2017.874016   63.685039     4.212598
# std      1.641505    1.888632     1.247169   36.415525     5.207793
# min      1.000000    1.000000  2016.000000    1.000000     0.000000
# 25%      2.000000    2.000000  2017.000000   32.500000     0.000000
# 50%      4.000000    4.000000  2018.000000   64.000000     5.000000
# 75%      5.000000    5.500000  2019.000000   94.500000     7.000000
# max      6.000000    6.000000  2020.000000  125.000000    50.000000
#
#        Win_By_Runs  toss_winner_code  toss_decision  winner_code
# count   127.000000        127.000000     127.000000   127.000000
# mean      8.259843          3.740157       1.259843     4.173228
# std      16.851929          1.778231       0.440285     1.881803
# min       0.000000          1.000000       1.000000     1.000000
# 25%       0.000000          2.000000       1.000000     3.000000
# 50%       0.000000          4.000000       1.000000     4.000000
# 75%       5.500000          5.000000       2.000000     6.000000
# max      67.000000          6.000000       2.000000    10.000000

# %%
dicVal = encode['winner_code']
print(dicVal['KK']) #key value
print(list(dicVal.keys())[list(dicVal.values()).index(1)]) #find key by value search
# Out:
# 1
# KK

# %%
matches = matches[['Team1_Code','Team2_Code','toss_winner_code','toss_decision','Win_By_Wkts','Win_By_Runs','winner_code']]
matches.head()
# Out:
#    Team1_Code  Team2_Code  toss_winner_code  toss_decision  Win_By_Wkts  \
# 0           4           6                 4              1            8
# 1           1           2                 1              1            7
# 2           5           4                 5              1            0
# 3           6           1                 6              1            8
# 4           2           5                 5              2            9
#
#    Win_By_Runs  winner_code
# 0            0            6
# 1            0            1
# 2           24            5
# 3            0            6
# 4            0            5

# %%
df = pd.DataFrame(matches)
df.describe()
# Out:
#        Team1_Code  Team2_Code  toss_winner_code  toss_decision  Win_By_Wkts  \
# count  127.000000  127.000000        127.000000     127.000000   127.000000
# mean     3.543307    3.755906          3.740157       1.259843     4.212598
# std      1.641505    1.888632          1.778231       0.440285     5.207793
# min      1.000000    1.000000          1.000000       1.000000     0.000000
# 25%      2.000000    2.000000          2.000000       1.000000     0.000000
# 50%      4.000000    4.000000          4.000000       1.000000     5.000000
# 75%      5.000000    5.500000          5.000000       2.000000     7.000000
# max      6.000000    6.000000          6.000000       2.000000    50.000000
#
#        Win_By_Runs  winner_code
# count   127.000000   127.000000
# mean      8.259843     4.173228
# std      16.851929     1.881803
# min       0.000000     1.000000
# 25%       0.000000     3.000000
# 50%       0.000000     4.000000
# 75%       5.500000     6.000000
# max      67.000000    10.000000

# %%
temp1=df['toss_winner_code'].value_counts(sort=True)
temp2=df['winner_code'].value_counts(sort=True)
#'No of toss winners by each team'
print('No of toss winners by each team')
for idx, val in temp1.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
print('No of match winners by each team')
for idx, val in temp2.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
# Out:
# No of toss winners by each team
# PZ -> 33
# QG -> 23
# KK -> 23
# IU -> 21
# LQ -> 16
# MS -> 11
# No of match winners by each team
# QG -> 30
# PZ -> 28
# IU -> 27
# KK -> 18
# MS -> 10
# LQ -> 10
# MA -> 2
# MT -> 2

# %%
df['winner_code'].hist(bins=40)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Count of toss wins')
ax1.set_title("toss winners")
temp1.plot(kind='bar')

ax2 = fig.add_subplot(122)
temp2.plot(kind = 'bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('count of matches won')
ax2.set_title("Match winners")
# Out:
# Text(0.5, 1.0, 'Match winners')

# %%
 df.apply(lambda x: sum(x.isnull()),axis=0) 
    #find the null values in every column
# Out:
# Team1_Code          0
# Team2_Code          0
# toss_winner_code    0
# toss_decision       0
# Win_By_Wkts         0
# Win_By_Runs         0
# winner_code         0
# dtype: int64

# %%
df.shape
df.head(2)
# Out:
#    Team1_Code  Team2_Code  toss_winner_code  toss_decision  Win_By_Wkts  \
# 0           4           6                 4              1            8
# 1           1           2                 1              1            7
#
#    Win_By_Runs  winner_code
# 0            0            6
# 1            0            1

# %%
df.isnull()
# Out:
#      Team1_Code  Team2_Code  toss_winner_code  toss_decision  Win_By_Wkts  \
# 0         False       False             False          False        False
# 1         False       False             False          False        False
# 2         False       False             False          False        False
# 3         False       False             False          False        False
# 4         False       False             False          False        False
# ..          ...         ...               ...            ...          ...
# 122       False       False             False          False        False
# 123       False       False             False          False        False
# 124       False       False             False          False        False
# 125       False       False             False          False        False
# 126       False       False             False          False        False
#
#      Win_By_Runs  winner_code
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# ..           ...          ...
# 122        False        False
# 123        False        False
# 124        False        False
# 125        False        False
# 126        False        False
#
# [127 rows x 7 columns]

# %%
df.head()
# Out:
#    Team1_Code  Team2_Code  toss_winner_code  toss_decision  Win_By_Wkts  \
# 0           4           6                 4              1            8
# 1           1           2                 1              1            7
# 2           5           4                 5              1            0
# 3           6           1                 6              1            8
# 4           2           5                 5              2            9
#
#    Win_By_Runs  winner_code
# 0            0            6
# 1            0            1
# 2           24            5
# 3            0            6
# 4            0            5

# %% [markdown]
# #  Identifying features and target

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %% [markdown]
# # Splitting train and test data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.1) 

X_train.shape
# Out:
# (114, 6)

# %% [markdown]
# # Building models

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

def model_():
    model = Sequential()

    model.add(Dense(10,input_shape=(X.shape[1],),activation='tanh'))
    model.add(Dense(8,activation='tanh'))
    model.add(Dense(6,activation='tanh'))
    model.add(Dense(1))

    model.compile(optimizer=Adam(lr=0.04), loss='mse', metrics=['mae'])

    model.summary()
    return model

# %% [markdown]
# # Fitting & validating model

# %%
model = model_()
history = model.fit(X_train,y_train,epochs=10,validation_data = (X_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                70
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 219
# Trainable params: 219
# Non-trainable params: 0
# _________________________________________________________________
# Train on 114 samples, validate on 13 samples
# Epoch 1/10
# 114/114 [==============================] - 0s 1ms/step - loss: 12.6429 - mae: 3.0810 - val_loss: 4.9011 - val_mae: 1.9332
# Epoch 2/10
# 114/114 [==============================] - 0s 70us/step - loss: 4.9696 - mae: 1.9120 - val_loss: 2.5631 - val_mae: 1.4085
# Epoch 3/10
# 114/114 [==============================] - 0s 70us/step - loss: 3.7816 - mae: 1.5709 - val_loss: 2.3789 - val_mae: 1.2725
# Epoch 4/10
# 114/114 [==============================] - 0s 70us/step - loss: 3.8128 - mae: 1.5242 - val_loss: 2.6326 - val_mae: 1.2481
# Epoch 5/10
# 114/114 [==============================] - 0s 105us/step - loss: 4.0446 - mae: 1.5466 - val_loss: 2.6078 - val_mae: 1.2499
# Epoch 6/10
# 114/114 [==============================] - 0s 105us/step - loss: 3.9076 - mae: 1.5349 - val_loss: 2.4226 - val_mae: 1.2671
# Epoch 7/10
# 114/114 [==============================] - 0s 105us/step - loss: 3.7295 - mae: 1.5313 - val_loss: 2.3354 - val_mae: 1.2944
# Epoch 8/10
# 114/114 [==============================] - 0s 140us/step - loss: 3.6280 - mae: 1.5138 - val_loss: 2.4047 - val_mae: 1.3228
# Epoch 9/10
# 114/114 [==============================] - 0s 140us/step - loss: 3.6922 - mae: 1.5405 - val_loss: 2.4290 - val_mae: 1.3392
# Epoch 10/10
# 114/114 [==============================] - 0s 105us/step - loss: 3.7170 - mae: 1.5568 - val_loss: 2.4224 - val_mae: 1.3366

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
